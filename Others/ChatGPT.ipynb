# %%
# Install library
# !pip install openai

# %%
import openai
model_engine = "text-davinci-003"
openai.api_key = "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"

# %%
def GPT(query):
    completion = openai.Completion.create(
        engine=model_engine,
        prompt=query,
        max_tokens=1024,
        n=1,
        stop=None,
        temperature=0.5,
    )
    response = completion.choices[0].text
    return response

# %%
# Specify you exit condition
exit_conditions = (":q", "quit", "exit")


while True:
    query = input("> ")
    if query in exit_conditions:
        break
    else:
        print ("ChatGPT: %s " % (GPT(query)))
# Out:
# ChatGPT:  file
#
# Q1: What comes after three in counting to five?
# A. Six
# B. Four
# C. Five
# D. Two
#
# Q2: How many numbers are there in counting to five?
# A. Six
# B. Five
# C. Four
# D. Three
# ChatGPT:
#
# Q1: What number comes after 4?
# A. 5
# B. 6
# C. 3
# D. 2
#
# Q2: How many numbers are there between 3 and 5?
# A. 2
# B. 3
# C. 4
# D. 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 10
#       8     break
#       9 else:
# ---> 10     print ("ChatGPT: %s " % (GPT(query)))
#
# Cell In[4], line 2, in GPT(query)
#       1 def GPT(query):
# ----> 2     completion = openai.Completion.create(
#       3         engine=model_engine,
#       4         prompt=query,
#       5         max_tokens=1024,
#       6         n=1,
#       7         stop=None,
#       8         temperature=0.5,
#       9     )
# ...

# %%
response = openai.Image.create(
  prompt="a white cat",
  n=1,
  size="1024x1024"
)
image_url = response['data'][0]['url']

from skimage import io
import matplotlib.pyplot as plt

image = io.imread(image_url)
plt.imshow(image)
plt.show()

# %%
import openai
import os

openai.api_key = "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"

# Define the prompt
prompt = "Hi ChatGPT, can you tell me a joke?"

# Generate the response using the OpenAI API
response = openai.Completion.create(
  engine="davinci",
  prompt=prompt,
  max_tokens=100,
  n=1,
  stop=None,
  temperature=0.5,
)

# Extract the response text
answer = response.choices[0].text.strip()

# Save the response to a text file
with open("chatGPT_responses.txt", "a") as f:
    f.write(answer + os.linesep)
