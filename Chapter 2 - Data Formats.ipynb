# %% [markdown]
# # Chapter 2 - Data Formats

# %%
import rasterio
from rasterio.plot import show
fp = r'Data/example1.tiff'
dataset = rasterio.open(fp)
show(dataset)
# Out:
# <AxesSubplot: >

# %%
# No. of Bands and Image resolution and Coordinate Reference System
dataset.count, dataset.height, dataset.width, dataset.crs
# Out:
# (1, 655, 800, CRS.from_epsg(32645))
