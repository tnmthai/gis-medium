# %%
from geotran import raster
path="/Users/thaitran/Documents/GitHub/gis-medium/Data/data/"
raster.plot(path+ 'RGB.byte.tif') 

raster.plot_contour(path+ 'RGB.byte.tif')

raster.plot_hist(path+ 'RGB.byte.tif',100)
